# %%
import pandas as pd
import matplotlib.pyplot as plt


df_vendas = pd.read_csv('vendas.csv')

# %%
df_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data            100 non-null    object
#  1   produto         100 non-null    object
#  2   categoria       100 non-null    object
#  3   quantidade      100 non-null    int64
#  4   preco_unitario  100 non-null    int64
#  5   cliente         100 non-null    object
#  6   regiao          100 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 5.6+ KB

# %%
df_vendas.head()
# Out:
#          data            produto    categoria  quantidade  preco_unitario  \
# 0  2025-12-09          Headset G  Periféricos           1            2759
# 1  2025-03-12          Armário P       Móveis           2            4516
# 2  2025-11-24  Mesa Escritório N       Móveis           1            4347
# 3  2025-09-14            Tênis T    Vestuário           3            3046
# 4  2025-08-03             Boné V    Vestuário           2            4453
#
#     cliente        regiao
# 0  Fernanda       Sudeste
# 1    Rafael         Norte
# 2    Rafael       Sudeste
# 3       Ana         Norte
# 4     Bruno  Centro-Oeste

# %%
df_vendas.shape[0]
# Out:
# 100

# %%
df_vendas["Faturamento"]= df_vendas["preco_unitario"].sum()
print(df_vendas["preco_unitario"].sum())
# Out:
# 276361

# %%
Filtro = df_vendas[df_vendas["categoria"].str.contains("Eletrônicos")] 
print(Filtro)
# Out:
#           data     produto    categoria  quantidade  preco_unitario   cliente  \
# 5   2025-07-24    Tablet D  Eletrônicos           2            4893  Fernanda
# 6   2025-05-20   Monitor B  Eletrônicos           1            3060     Lucas
# 9   2025-06-01   Celular A  Eletrônicos           3             516      João
# 10  2025-04-22   Celular A  Eletrônicos           2            1018  Fernanda
# 13  2025-11-24  Notebook X  Eletrônicos           1            2670       Ana
# 14  2025-05-30    Tablet D  Eletrônicos           4            2575     Maria
# 15  2025-09-19  Notebook X  Eletrônicos           2            2778    Rafael
# 27  2025-01-30  Notebook X  Eletrônicos           5            1006     Lucas
# 32  2025-07-07    Tablet D  Eletrônicos           2            2533    Camila
# 33  2025-11-20  Notebook X  Eletrônicos           4            3998     Pedro
# 36  2025-08-01      Fone C  Eletrônicos           5            2433     Pedro
# ...

# %%
df_vendas.sort_values(by='quantidade')
# Out:
#           data            produto    categoria  quantidade  preco_unitario  \
# 0   2025-12-09          Headset G  Periféricos           1            2759
# 2   2025-11-24  Mesa Escritório N       Móveis           1            4347
# 6   2025-05-20          Monitor B  Eletrônicos           1            3060
# 11  2025-07-10            Tênis T    Vestuário           1            4967
# 13  2025-11-24         Notebook X  Eletrônicos           1            2670
# ..         ...                ...          ...         ...             ...
# 73  2025-08-15          Monitor B  Eletrônicos           5            3644
# 83  2025-11-13             Fone C  Eletrônicos           5            4939
# 64  2025-08-20           Webcam H  Periféricos           5            2022
# 97  2025-03-15          Celular A  Eletrônicos           5            4390
# 98  2025-02-07            Calça U    Vestuário           5            2472
#
#      cliente        regiao  Faturamento
# ...

# %%
df_vendas['regiao'].value_counts()
# Out:
# regiao
# Sudeste         27
# Sul             22
# Norte           20
# Nordeste        16
# Centro-Oeste    15
# Name: count, dtype: int64
